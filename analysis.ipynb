# %% [markdown]
# # load data

# %%
from pathlib import Path

from analysis import Subject, logger

logger.setLevel("INFO")

# %%
timer_subj_roots = []
control_subj_roots = []

results_root = Path("./results/subjects")
for root in results_root.glob("trial_*"):
    if root.name.endswith("timer"):
        timer_subj_roots.append(root)
    else:
        control_subj_roots.append(root)


for root in timer_subj_roots:
    subj = Subject(root)
    print(subj)

for root in control_subj_roots:
    subj = Subject(root)
    print(subj)
# Out:
# Subject(name=kasem, timestamp=2024-12-06 14:12:09.425377, with_timer=True)
# Subject(name=elenatrianti, timestamp=2024-12-06 15:03:33.711301, with_timer=True)
# Subject(name=kareem, timestamp=2024-12-07 21:48:20.965403, with_timer=True)
# Subject(name=yeshi, timestamp=2024-12-06 15:22:07.403782, with_timer=True)
# Subject(name=jonah, timestamp=2024-12-06 12:18:05.277452, with_timer=True)
# Subject(name=elliott, timestamp=2024-12-06 15:11:53.855750, with_timer=False)
# Subject(name=dai, timestamp=2024-12-06 10:27:25.458122, with_timer=False)
# Subject(name=osman, timestamp=2024-12-06 16:06:50.984989, with_timer=False)
# Subject(name=mathilde, timestamp=2024-12-06 14:54:13.492560, with_timer=False)
# Subject(name=noemie, timestamp=2024-12-06 14:01:36.214106, with_timer=False)

# %%
subj = Subject(control_subj_roots[0])
df_idt = subj.plot_fixations_idt(1)
# Out:
# /Users/hagayuya/Desktop/UEF_lectures/EyeTracking/ET-FinalProject-Data-Analysis/.venv/lib/python3.12/site-packages/matplotlib/collections.py:1109: UserWarning: Collection without array used. Make sure to specify the values to be colormapped via the `c` argument.
#   warnings.warn("Collection without array used. Make sure to "

# %%
subj = Subject(timer_subj_roots[0])
df_idt = subj.plot_fixations_idt(1)
# Out:
# /Users/hagayuya/Desktop/UEF_lectures/EyeTracking/ET-FinalProject-Data-Analysis/.venv/lib/python3.12/site-packages/matplotlib/collections.py:1109: UserWarning: Collection without array used. Make sure to specify the values to be colormapped via the `c` argument.
#   warnings.warn("Collection without array used. Make sure to "
